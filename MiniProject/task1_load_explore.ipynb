# %%
import pandas as pd

# %%
df = pd.read_csv("ai_learning_lab.csv")

# %%
print(df.shape)
# Out:
# (110, 12)

# %%
print(df.head())
# Out:
#   student_id    student_name      batch         topic attendance  \
# 0      ST001      Rakesh P    AIML-2603          JSON    PRESENT
# 1      ST002    Aarav Sharma  AIML-2602    SQL Basics     ABSENT
# 2      ST003  Harsha Vardhan  AIML-2605           EDA    PRESENT
# 3      ST004       Sirisha P  AIML-2605           eda    present
# 4      ST005     Yashwanth K  AIML-2603  NumPy Basics    Absent
#
#    assignment_score  quiz_score lab_completed  study_hours  feedback_rating  \
# 0              -5.0       -10.0           yes          8.6              3.0
# 1              68.0        65.0            no          9.8              4.0
# 2              35.0        68.0            No          4.7              3.0
# 3              96.0        27.0           YES          NaN              3.0
# 4              56.0        94.0          Yes           4.7              4.0
#
#    tool_used api_used
# 0    VS Code       No
# 1     colab       yes
# 2     colab       Yes
# 3   jupyter       yes
# 4    Jupyter      No

# %%
print(df.columns)
# Out:
# Index(['student_id', 'student_name', 'batch', 'topic', 'attendance',
#        'assignment_score', 'quiz_score', 'lab_completed', 'study_hours',
#        'feedback_rating', 'tool_used', 'api_used'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        110 non-null    object
#  1   student_name      110 non-null    object
#  2   batch             110 non-null    object
#  3   topic             110 non-null    object
#  4   attendance        110 non-null    object
#  5   assignment_score  98 non-null     float64
#  6   quiz_score        102 non-null    float64
#  7   lab_completed     110 non-null    object
#  8   study_hours       101 non-null    float64
#  9   feedback_rating   104 non-null    float64
#  10  tool_used         110 non-null    object
#  11  api_used          110 non-null    object
# dtypes: float64(4), object(8)
# memory usage: 10.4+ KB

# %%
print(df.isnull().sum())
# Out:
# student_id           0
# student_name         0
# batch                0
# topic                0
# attendance           0
# assignment_score    12
# quiz_score           8
# lab_completed        0
# study_hours          9
# feedback_rating      6
# tool_used            0
# api_used             0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 5

# %%
print(df["topic"].value_counts())
# Out:
# topic
# Loops                10
#  Python Basics        9
# pandas loading        9
# eda                   8
# Pandas Filtering      7
# Decision Making       6
# JSON                  6
# EDA                   6
# Functions             5
#  APIs and Ethics      5
# Pandas Grouping       5
# AI Landscape          5
# SQL basics            4
# Matplotlib            4
# Data Collections      4
# Pandas Loading        3
# NumPy Basics          3
# APIs and Ethics       3
# Python Basics         3
# File Handling         3
# SQL Basics            2
# Name: count, dtype: int64

# %%
print(df["attendance"].value_counts())
# Out:
# attendance
# ABSENT       16
#  Present     16
#  Absent      15
# PRESENT      15
# Present      15
# Absent       14
# present      10
# absent        9
# Name: count, dtype: int64
